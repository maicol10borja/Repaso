# %% [markdown]
# <span style="font-size:20px; font-family:sans-serif;">Instituto Superior Tecnológico Quito</span>
#
#
# *Michael Borja*

# %% [markdown]
# # Regresión Lineal: Coste de un incidente de seguridad

# %% [markdown]
# En este ejercicio se explican los fundamentos básicos de la regresión lineal aplicada a un caso de uso sencillo relacionado con la Ciberseguridad.

# %% [markdown]
# ## Enunciado del ejercicio

# %% [markdown]
# El ejercicio consiste en predecir el coste de un incidente de seguridad en base al número de equipos que se han visto afectados. El conjunto de datos es generado de manera aleatoria.

# %% [markdown]
# ### 0. Imports

# %%
# Instalacion de librerías externas
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install scikit-learn
# Out:
# Acceso denegado.
# Acceso denegado.
# Acceso denegado.
# Acceso denegado.

# %% [markdown]
# ### 1. Generación del conjunto de datos

# %%
import numpy as np

X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

print("La longitud del conjunto de datos es:", len(X))
# Out:
# La longitud del conjunto de datos es: 100

# %% [markdown]
# ### 2. Visualización del conjunto de datos

# %%
import matplotlib.pyplot as plt  # libreria para graficas

# crear grafico de dispersion entre X y y
plt.scatter(X, y)
plt.title("Visualizacion de datos")
plt.xlabel("X")
plt.ylabel("y")
plt.grid(True)
plt.show()

# %% [markdown]
# ### 3. Modificación del conjunto de datos

# %%
# agregar columna de unos para tener termino independiente
X_mod = np.c_[np.ones((100, 1)), X]

# mostrar forma del nuevo array
print("X_mod shape:", X_mod.shape)
# Out:
# X_mod shape: (100, 2)

# %% [markdown]
# ### 4. Construcción del modelo

# %%
from sklearn.linear_model import LinearRegression  # libreria para modelo

# crear el modelo de regresion
modelo = LinearRegression()

# entrenar el modelo con los datos
modelo.fit(X, y)

# mostrar los coeficientes aprendidos
print("Coeficiente:", modelo.coef_)
print("Intercepcion:", modelo.intercept_)
# Out:
# Coeficiente: [[2.96916921]]
# Intercepcion: [4.17705748]

# %% [markdown]
# ### 5. Predicción de nuevos ejemplos

# %%
# crear nuevos puntos para predecir
X_nuevo = np.array([[0], [2]])

# usar el modelo para predecir esos puntos
y_pred = modelo.predict(X_nuevo)

# graficar puntos originales y linea de prediccion
plt.scatter(X, y)
plt.plot(X_nuevo, y_pred, color='red')  # linea roja de prediccion
plt.title("Prediccion con regresion lineal")
plt.xlabel("X")
plt.ylabel("y")
plt.grid(True)
plt.show()

# %% [markdown]
# # Git Repo
# https://github.com/maicol10borja/Repaso.git
